# %% [markdown]
# ## Titanic Project

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns

# %% [markdown]
# ### load dataset

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Check Data Types

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
{col : df[col].nunique() for col in df if df[col].dtype == object}
# Out:
# {'sex': 2, 'embarked': 3, 'who': 3, 'embark_town': 3, 'alive': 2}

# %%
df = df.astype({
    'sex': 'category',
    'embarked' : 'category',
    'who' : 'category',
    'alive': 'category',
    'embark_town': 'category'
}
)

# %%
df.alive = df.alive.cat.codes

# %%
df.sex = df.sex.cat.codes

# %%
df[['alive','sex']]
# Out:
#      alive  sex
# 0        0    1
# 1        1    0
# 2        1    0
# 3        1    0
# 4        0    1
# ..     ...  ...
# 886      0    1
# 887      1    0
# 888      0    0
# 889      1    1
# 890      0    1
#
# [891 rows x 2 columns]

# %% [markdown]
# ### Check Correlation

# %%
df.corr()
# Out:
#             survived    pclass       sex       age     sibsp     parch  \
# survived    1.000000 -0.338481 -0.543351 -0.077221 -0.035322  0.081629
# pclass     -0.338481  1.000000  0.131900 -0.369226  0.083081  0.018443
# sex        -0.543351  0.131900  1.000000  0.093254 -0.114631 -0.245489
# age        -0.077221 -0.369226  0.093254  1.000000 -0.308247 -0.189119
# sibsp      -0.035322  0.083081 -0.114631 -0.308247  1.000000  0.414838
# parch       0.081629  0.018443 -0.245489 -0.189119  0.414838  1.000000
# fare        0.257307 -0.549500 -0.182333  0.096067  0.159651  0.216225
# adult_male -0.557080  0.094035  0.908578  0.280328 -0.253586 -0.349943
# alive       1.000000 -0.338481 -0.543351 -0.077221 -0.035322  0.081629
# alone      -0.203367  0.135207  0.303646  0.198270 -0.584471 -0.583398
#
#                 fare  adult_male     alive     alone
# survived    0.257307   -0.557080  1.000000 -0.203367
# pclass     -0.549500    0.094035 -0.338481  0.135207
# sex        -0.182333    0.908578 -0.543351  0.303646
# age         0.096067    0.280328 -0.077221  0.198270
# sibsp       0.159651   -0.253586 -0.035322 -0.584471
# parch       0.216225   -0.349943  0.081629 -0.583398
# fare        1.000000   -0.182024  0.257307 -0.271832
# adult_male -0.182024    1.000000 -0.557080  0.404744
# alive       0.257307   -0.557080  1.000000 -0.203367
# alone      -0.271832    0.404744 -0.203367  1.000000

# %%
df.corr().style.background_gradient(cmap = 'Greens')
# Out:
# <style  type="text/css" >
#     #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row0_col0 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row0_col1 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row0_col2 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row0_col3 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row0_col4 {
#             background-color:  #aadda4;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row0_col5 {
#             background-color:  #91d28e;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row0_col6 {
#             background-color:  #6bc072;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row0_col7 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row0_col8 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row0_col9 {
#             background-color:  #caeac3;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row1_col0 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row1_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row1_col2 {
#             background-color:  #8ace88;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row1_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row1_col4 {
#             background-color:  #91d28e;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row1_col5 {
#             background-color:  #9fd899;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row1_col6 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row1_col7 {
#             background-color:  #91d28e;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row1_col8 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row1_col9 {
#             background-color:  #84cc83;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row2_col0 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row2_col1 {
#             background-color:  #8ace88;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row2_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row2_col3 {
#             background-color:  #acdea6;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row2_col4 {
#             background-color:  #bae3b3;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row2_col5 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row2_col6 {
#             background-color:  #cbeac4;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row2_col7 {
#             background-color:  #005723;
#             color:  #f1f1f1;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row2_col8 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row2_col9 {
#             background-color:  #5bb86a;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row3_col0 {
#             background-color:  #b6e2af;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row3_col1 {
#             background-color:  #e7f6e2;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row3_col2 {
#             background-color:  #94d390;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row3_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row3_col4 {
#             background-color:  #daf0d4;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row3_col5 {
#             background-color:  #c8e9c1;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row3_col6 {
#             background-color:  #92d28f;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row3_col7 {
#             background-color:  #65bd6f;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row3_col8 {
#             background-color:  #b6e2af;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row3_col9 {
#             background-color:  #76c578;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row4_col0 {
#             background-color:  #aedea7;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row4_col1 {
#             background-color:  #95d391;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row4_col2 {
#             background-color:  #bee5b8;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row4_col3 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row4_col4 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row4_col5 {
#             background-color:  #3fa95c;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row4_col6 {
#             background-color:  #83cb82;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row4_col7 {
#             background-color:  #d5efcf;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row4_col8 {
#             background-color:  #aedea7;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row4_col9 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row5_col0 {
#             background-color:  #94d390;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row5_col1 {
#             background-color:  #a4da9e;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row5_col2 {
#             background-color:  #d5efcf;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row5_col3 {
#             background-color:  #e4f5df;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row5_col4 {
#             background-color:  #3fa95c;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row5_col5 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row5_col6 {
#             background-color:  #76c578;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row5_col7 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row5_col8 {
#             background-color:  #94d390;
#             color:  #000000;
#         }    #T_85d320f0_a9de_11ed_afaa_3d6182b703c7row5_col9 {
#             background-color:  #f7fcf5;
#             color:  #000000;

# %%
df.drop(columns = ['alive'], inplace = True)

# %%
df
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    1  22.0      1      0   7.2500        S   Third
# 1           1       1    0  38.0      1      0  71.2833        C   First
# 2           1       3    0  26.0      0      0   7.9250        S   Third
# 3           1       1    0  35.0      1      0  53.1000        S   First
# 4           0       3    1  35.0      0      0   8.0500        S   Third
# ..        ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886         0       2    1  27.0      0      0  13.0000        S  Second
# 887         1       1    0  19.0      0      0  30.0000        S   First
# 888         0       3    0   NaN      1      2  23.4500        S   Third
# 889         1       1    1  26.0      0      0  30.0000        C   First
# 890         0       3    1  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town  alone
# 0      man        True  NaN  Southampton  False
# 1    woman       False    C    Cherbourg  False
# 2    woman       False  NaN  Southampton   True
# 3    woman       False    C  Southampton  False
# 4      man        True  NaN  Southampton   True
# ..     ...         ...  ...          ...    ...
# 886    man        True  NaN  Southampton   True
# 887  woman       False    B  Southampton   True
# 888  woman       False  NaN  Southampton  False
# 889    man        True    C    Cherbourg   True
# 890    man        True  NaN   Queenstown   True
#
# [891 rows x 14 columns]

# %% [markdown]
# ### Describe

# %%
df.describe()
# Out:
#          survived      pclass         sex         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.699118    0.523008    0.381594
# std      0.486592    0.836071    0.477990   14.526497    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   20.125000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   38.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
df['embark_char'] = df.embark_town.str.get(0)

# %%
df
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    1  22.0      1      0   7.2500        S   Third
# 1           1       1    0  38.0      1      0  71.2833        C   First
# 2           1       3    0  26.0      0      0   7.9250        S   Third
# 3           1       1    0  35.0      1      0  53.1000        S   First
# 4           0       3    1  35.0      0      0   8.0500        S   Third
# ..        ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886         0       2    1  27.0      0      0  13.0000        S  Second
# 887         1       1    0  19.0      0      0  30.0000        S   First
# 888         0       3    0   NaN      1      2  23.4500        S   Third
# 889         1       1    1  26.0      0      0  30.0000        C   First
# 890         0       3    1  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town  alone embark_char
# 0      man        True  NaN  Southampton  False           S
# 1    woman       False    C    Cherbourg  False           C
# 2    woman       False  NaN  Southampton   True           S
# 3    woman       False    C  Southampton  False           S
# 4      man        True  NaN  Southampton   True           S
# ..     ...         ...  ...          ...    ...         ...
# 886    man        True  NaN  Southampton   True           S
# 887  woman       False    B  Southampton   True           S
# 888  woman       False  NaN  Southampton  False           S
# 889    man        True    C    Cherbourg   True           C
# 890    man        True  NaN   Queenstown   True           Q
#
# [891 rows x 15 columns]

# %%
sum(df.embarked == df.embark_char)/df.shape[0]
# Out:
# 0.9977553310886644

# %%
df.drop(columns = 'embark_town', inplace = True)

# %%
df.drop(columns = 'embark_char', inplace = True)

# %%
df
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    1  22.0      1      0   7.2500        S   Third
# 1           1       1    0  38.0      1      0  71.2833        C   First
# 2           1       3    0  26.0      0      0   7.9250        S   Third
# 3           1       1    0  35.0      1      0  53.1000        S   First
# 4           0       3    1  35.0      0      0   8.0500        S   Third
# ..        ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886         0       2    1  27.0      0      0  13.0000        S  Second
# 887         1       1    0  19.0      0      0  30.0000        S   First
# 888         0       3    0   NaN      1      2  23.4500        S   Third
# 889         1       1    1  26.0      0      0  30.0000        C   First
# 890         0       3    1  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  alone
# 0      man        True  NaN  False
# 1    woman       False    C  False
# 2    woman       False  NaN   True
# 3    woman       False    C  False
# 4      man        True  NaN   True
# ..     ...         ...  ...    ...
# 886    man        True  NaN   True
# 887  woman       False    B   True
# 888  woman       False  NaN  False
# 889    man        True    C   True
# 890    man        True  NaN   True
#
# [891 rows x 13 columns]

# %% [markdown]
# ### Missing Values Check

# %%
df.describe()
# Out:
#          survived      pclass         sex         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.699118    0.523008    0.381594
# std      0.486592    0.836071    0.477990   14.526497    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   20.125000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   38.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
df.isna().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age           177
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck          688
# alone           0
# dtype: int64

# %%
# %matplotlib inline
ax = sns.barplot(
    x=df.isna().sum() / df.shape[0] * 100,
    y=df.columns
)

# %%
df.drop(columns = 'deck', inplace = True)

# %%
df
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    1  22.0      1      0   7.2500        S   Third
# 1           1       1    0  38.0      1      0  71.2833        C   First
# 2           1       3    0  26.0      0      0   7.9250        S   Third
# 3           1       1    0  35.0      1      0  53.1000        S   First
# 4           0       3    1  35.0      0      0   8.0500        S   Third
# ..        ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886         0       2    1  27.0      0      0  13.0000        S  Second
# 887         1       1    0  19.0      0      0  30.0000        S   First
# 888         0       3    0   NaN      1      2  23.4500        S   Third
# 889         1       1    1  26.0      0      0  30.0000        C   First
# 890         0       3    1  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  alone
# 0      man        True  False
# 1    woman       False  False
# 2    woman       False   True
# 3    woman       False  False
# 4      man        True   True
# ..     ...         ...    ...
# 886    man        True   True
# 887  woman       False   True
# 888  woman       False  False
# 889    man        True   True
# 890    man        True   True
#
# [891 rows x 12 columns]

# %%
df.corr()
# Out:
#             survived    pclass       sex       age     sibsp     parch  \
# survived    1.000000 -0.338481 -0.543351 -0.077221 -0.035322  0.081629
# pclass     -0.338481  1.000000  0.131900 -0.369226  0.083081  0.018443
# sex        -0.543351  0.131900  1.000000  0.093254 -0.114631 -0.245489
# age        -0.077221 -0.369226  0.093254  1.000000 -0.308247 -0.189119
# sibsp      -0.035322  0.083081 -0.114631 -0.308247  1.000000  0.414838
# parch       0.081629  0.018443 -0.245489 -0.189119  0.414838  1.000000
# fare        0.257307 -0.549500 -0.182333  0.096067  0.159651  0.216225
# adult_male -0.557080  0.094035  0.908578  0.280328 -0.253586 -0.349943
# alone      -0.203367  0.135207  0.303646  0.198270 -0.584471 -0.583398
#
#                 fare  adult_male     alone
# survived    0.257307   -0.557080 -0.203367
# pclass     -0.549500    0.094035  0.135207
# sex        -0.182333    0.908578  0.303646
# age         0.096067    0.280328  0.198270
# sibsp       0.159651   -0.253586 -0.584471
# parch       0.216225   -0.349943 -0.583398
# fare        1.000000   -0.182024 -0.271832
# adult_male -0.182024    1.000000  0.404744
# alone      -0.271832    0.404744  1.000000

# %%
df.groupby(['adult_male', 'sex']).age.mean()
# Out:
# adult_male  sex
# False       0      27.915709
#             1       5.466750
# True        1      33.173123
# Name: age, dtype: float64

# %%
# %matplotlib inline
df['age_1'] = df['age'].fillna(df.groupby(['adult_male', 'sex'])['age'].transform('mean'))
df['age_2'] = df['age'].fillna(df.groupby(['adult_male', 'sex', 'sibsp', 'alone'])['age'].transform('mean'))
ax = sns.histplot(df.age)
ax = sns.histplot(df.age_1, ax=ax, color='y', label='age_1')
ax = sns.histplot(df.age_2, ax=ax, color='g', label='age_2')

# %%
! pip install --upgrade seaborn
# Out:
# Requirement already up-to-date: seaborn in /home/abolfazl/anaconda3/lib/python3.7/site-packages (0.12.2)
# Requirement already satisfied, skipping upgrade: pandas>=0.25 in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from seaborn) (1.0.1)
# Requirement already satisfied, skipping upgrade: numpy!=1.24.0,>=1.17 in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from seaborn) (1.18.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.6.1,>=3.1 in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from seaborn) (3.5.3)
# Requirement already satisfied, skipping upgrade: typing_extensions; python_version < "3.8" in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from seaborn) (4.3.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from pandas>=0.25->seaborn) (2019.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from pandas>=0.25->seaborn) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.10.0)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (20.1)
# Requirement already satisfied, skipping upgrade: fonttools>=4.22.0 in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.2.1 in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.4.6)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (7.0.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas>=0.25->seaborn) (1.14.0)
# Requirement already satisfied, skipping upgrade: setuptools in /home/abolfazl/anaconda3/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib!=3.6.1,>=3.1->seaborn) (45.2.0.post20200210)

# %%
pip install -U seaborn
